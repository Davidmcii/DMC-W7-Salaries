# %%
#%pip install pycountry

# %%
import numpy as np
import pandas as pd

import pylab as plt
import seaborn as sns

import pycountry

# %%
salaries=pd.read_csv('../1-Input/salaries_data.csv')

salaries
# Out:
#      work_year experience_level employment_type  \
# 0         2022               SE              FT
# 1         2022               SE              FT
# 2         2021               MI              FT
# 3         2021               MI              CT
# 4         2021               MI              FT
# ..         ...              ...             ...
# 495       2022               SE              FT
# 496       2021               EN              FT
# 497       2022               SE              FT
# 498       2021               MI              FT
# 499       2021               EN              FT
#
#                              job_title  salary_in_usd employee_residence  \
# 0                        Data Engineer         140250                 US
# 1                        Data Engineer         135000                 US
# 2                      BI Data Analyst         100000                 US
# 3                          ML Engineer         270000                 US
# ...

# %%
testeo=pd.read_csv('../1-Input/test.csv')

testeo
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               SE              FT  Machine Learning Scientist
# 1         2020               MI              FT           Lead Data Analyst
# 2         2020               MI              FT                Data Analyst
# 3         2020               MI              FT   Machine Learning Engineer
# 4         2020               MI              FT        Product Data Analyst
# ..         ...              ...             ...                         ...
# 102       2022               SE              FT                Data Analyst
# 103       2022               SE              FT              Data Architect
# 104       2022               SE              FT              Data Scientist
# 105       2022               EN              FT                Data Analyst
# 106       2022               SE              FT                Data Analyst
#
# ...

# %%
tog=salaries.append(testeo)

tog
# Out:
# C:\Users\David MC\AppData\Local\Temp\ipykernel_8604\278992757.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tog=salaries.append(testeo)
#      work_year experience_level employment_type        job_title  \
# 0         2022               SE              FT    Data Engineer
# 1         2022               SE              FT    Data Engineer
# 2         2021               MI              FT  BI Data Analyst
# 3         2021               MI              CT      ML Engineer
# 4         2021               MI              FT    Data Engineer
# ..         ...              ...             ...              ...
# 102       2022               SE              FT     Data Analyst
# 103       2022               SE              FT   Data Architect
# 104       2022               SE              FT   Data Scientist
# 105       2022               EN              FT     Data Analyst
# ...

# %%
tog.employment_type.unique()
# Out:
# array(['FT', 'CT', 'FL', 'PT'], dtype=object)

# %%
tog.experience_level.unique()
# Out:
# array(['SE', 'MI', 'EN', 'EX'], dtype=object)

# %%
plt.figure(figsize=(15,10))

plt.scatter(tog.salary_in_usd, tog.experience_level)
plt.xlabel('salary')
plt.ylabel('descrip');

# %%
tog.employment_type.unique()
# Out:
# array(['FT', 'CT', 'FL', 'PT'], dtype=object)

# %%
tog.loc[(tog.employment_type=='PT')]
# Out:
#      work_year experience_level employment_type  \
# 62        2021               MI              PT
# 91        2022               MI              PT
# 199       2022               EN              PT
# 201       2021               EN              PT
# 251       2021               EN              PT
# 274       2020               EN              PT
# 366       2021               EN              PT
# 481       2021               MI              PT
# 13        2020               EN              PT
# 40        2021               EN              PT
#
#                          job_title  salary_in_usd employee_residence  \
# 62   3D Computer Vision Researcher         5409.0                 IN
# 91                   Data Engineer        54957.0                 DE
# 199                 Data Scientist       100000.0                 DZ
# 201                   Data Analyst        10354.0                 ES
# 251                   AI Scientist        12000.0                 PK
# ...

# %%
for i in range(len(tog)):
    if tog.employment_type.iloc[i]=='PT':
        tog.employment_type.iloc[i]='FT'
        tog.salary_in_usd.iloc[i]=tog.salary_in_usd.iloc[i]*2
# Out:
# C:\Users\David MC\AppData\Local\Temp\ipykernel_8604\3612159012.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tog.employment_type.iloc[i]='FT'
# C:\Users\David MC\AppData\Local\Temp\ipykernel_8604\3612159012.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tog.salary_in_usd.iloc[i]=tog.salary_in_usd.iloc[i]*2

# %%
for i in range(len(tog)):
    if tog.experience_level.iloc[i]=='MI' and tog.salary_in_usd.iloc[i]>175000:
        tog.experience_level.iloc[i]='SE'
# Out:
# C:\Users\David MC\AppData\Local\Temp\ipykernel_8604\721764247.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tog.experience_level.iloc[i]='SE'

# %%
for i in range(len(tog)):
    if tog.experience_level.iloc[i]=='EN' and tog.salary_in_usd.iloc[i]>100000:
        tog.experience_level.iloc[i]='SE'
# Out:
# C:\Users\David MC\AppData\Local\Temp\ipykernel_8604\2598381478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tog.experience_level.iloc[i]='SE'

# %%
for i in range(len(tog)):
    if tog.experience_level.iloc[i]=='SE' and tog.salary_in_usd.iloc[i]<50000:
        tog.experience_level.iloc[i]='EN'
# Out:
# C:\Users\David MC\AppData\Local\Temp\ipykernel_8604\1558039889.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tog.experience_level.iloc[i]='EN'

# %%
tog.employment_type.unique()
# Out:
# array(['FT', 'CT', 'FL'], dtype=object)

# %%
list_jobs=tog.job_title.unique()

list_jobs
# Out:
# array(['Data Engineer', 'BI Data Analyst', 'ML Engineer',
#        'Machine Learning Scientist', 'Data Scientist', 'Data Analyst',
#        'Machine Learning Engineer', 'Principal Data Scientist',
#        'Data Engineering Manager', 'Data Analytics Manager',
#        'Big Data Engineer', 'Research Scientist',
#        'Machine Learning Developer', 'Computer Vision Engineer',
#        'AI Scientist', 'Machine Learning Manager', 'Lead Data Scientist',
#        'Director of Data Science', '3D Computer Vision Researcher',
#        'Data Specialist', 'Applied Data Scientist',
#        'Data Science Engineer', 'Head of Data', 'Analytics Engineer',
#        'ETL Developer', 'Marketing Data Analyst', 'Data Architect',
#        'Data Science Consultant', 'Principal Data Analyst',
#        'Head of Data Science', 'Lead Data Engineer',
#        'Data Science Manager', 'Applied Machine Learning Scientist',
#        'Lead Data Analyst', 'Cloud Data Engineer',
# ...

# %%
plt.figure(figsize=(15,10))

plt.scatter(tog.salary_in_usd, tog.job_title)
plt.xlabel('salary')
plt.ylabel('descrip');

# %%
tog.shape
# Out:
# (607, 9)

# %%
tog.loc[(tog.salary_in_usd>200000)]
# Out:
#      work_year experience_level employment_type                   job_title  \
# 3         2021               SE              CT                 ML Engineer
# 49        2022               SE              FT              Data Scientist
# 63        2020               SE              FT              Data Scientist
# 65        2022               SE              FT               Data Engineer
# 75        2021               SE              FT                 ML Engineer
# ..         ...              ...             ...                         ...
# 433       2021               SE              FT  Machine Learning Scientist
# 434       2022               SE              FT              Data Scientist
# 447       2022               SE              FT              Data Scientist
# 466       2022               SE              FT              Data Scientist
# 475       2022               SE              FT   Machine Learning Engineer
#
# ...

# %%
'''def funct(x):

    if 'Developer' in x:
        function='Developer'      
    if 'Engineer' in x:
        function='Engineer'
    if 'Analyst' in x:
        function='Analyst'	
    if 'Architect' in x:
        function='Architect'
    if 'Scientist' in x:
        function='Scientist'
    if 'Researcher' in x:
        function='Engineer'
    if 'Consultant' in x:
        function='Consultant'
    if 'Staff' in x:
        function='Analyst'
    if 'Principal' in x:
        function='Principal'
    if 'Lead' in x:
        function='Lead'
    if 'Manager' in x:
        function='Principal'
    if 'Specialist' in x:
        function='Principal'
    if 'Director' in x:
        function='Principal'
    if 'Head' in x:
        function='Lead'
    if 'Business' in x:
        function='Business'
    if 'Fina' in x:
        function='Finance'
    
    return function    

tog.job_title=tog.job_title.apply(lambda x: funct(x))

tog.job_title.unique()'''
# Out:
# "def funct(x):\n\n    if 'Developer' in x:\n        function='Developer'      \n    if 'Engineer' in x:\n        function='Engineer'\n    if 'Analyst' in x:\n        function='Analyst'\t\n    if 'Architect' in x:\n        function='Architect'\n    if 'Scientist' in x:\n        function='Scientist'\n    if 'Researcher' in x:\n        function='Engineer'\n    if 'Consultant' in x:\n        function='Consultant'\n    if 'Staff' in x:\n        function='Analyst'\n    if 'Principal' in x:\n        function='Principal'\n    if 'Lead' in x:\n        function='Lead'\n    if 'Manager' in x:\n        function='Principal'\n    if 'Specialist' in x:\n        function='Principal'\n    if 'Director' in x:\n        function='Principal'\n    if 'Head' in x:\n        function='Lead'\n    if 'Business' in x:\n        function='Business'\n    if 'Fina' in x:\n        function='Finance'\n    \n    return function    \n\ntog.job_title=tog.job_title.apply(lambda x: funct(x))\n\ntog.job_title.unique()"

# %%
def funct(x):

    if 'Developer' in x:
        function='Engineer'      
    if 'Engineer' in x:
        function='Engineer'
    if 'Analyst' in x:
        function='Analyst'	
    if 'Architect' in x:
        function='Principal'
    if 'Scientist' in x:
        function='Scientist'
    if 'Researcher' in x:
        function='Engineer'
    if 'Consultant' in x:
        function='Engineer'
    if 'Staff' in x:
        function='Analyst'
    if 'Principal' in x:
        function='Principal'
    if 'Lead' in x:
        function='Principal'
    if 'Manager' in x:
        function='Principal'
    if 'Specialist' in x:
        function='Principal'
    if 'Director' in x:
        function='Principal'
    if 'Head' in x:
        function='Principal'
    if 'Business' in x:
        function='Principal'
    if 'Fina' in x:
        function='Principal'
    
    return function    

tog.job_title=tog.job_title.apply(lambda x: funct(x))

tog.job_title.unique()
# Out:
# array(['Engineer', 'Analyst', 'Scientist', 'Principal'], dtype=object)

# %%
plt.figure(figsize=(15,10))

plt.scatter(tog.salary_in_usd, tog.job_title)
plt.xlabel('salary')
plt.ylabel('descrip');

# %%
plt.figure(figsize=(7,5))

plt.scatter(tog.salary_in_usd, tog.company_size)
plt.xlabel('salary')
plt.ylabel('descrip');

# %%
tog.company_size.unique()
# Out:
# array(['M', 'L', 'S'], dtype=object)

# %%
tog.company_size.unique()
# Out:
# array(['M', 'L', 'S'], dtype=object)

# %%
tog.job_title.unique()
# Out:
# array(['Engineer', 'Analyst', 'Scientist', 'Principal'], dtype=object)

# %%
tog.loc[(tog['job_title']=='Analyst')].count()
# Out:
# work_year             107
# experience_level      107
# employment_type       107
# job_title             107
# salary_in_usd          89
# employee_residence    107
# remote_ratio          107
# company_location      107
# company_size          107
# dtype: int64

# %%
tog.loc[(tog['company_location']!='US')].describe().T
# Out:
#                count          mean           std     min       25%      50%  \
# work_year      252.0   2021.198413      0.703093  2020.0   2021.00   2021.0
# salary_in_usd  204.0  67972.063725  40900.205585  2859.0  39752.75  63760.5
# remote_ratio   252.0     61.309524     39.933603     0.0     50.00     50.0
#
#                    75%       max
# work_year       2022.0    2022.0
# salary_in_usd  88654.0  225000.0
# remote_ratio     100.0     100.0

# %%
tog.loc[(tog['employee_residence']!='US')].describe().T
# Out:
#                count          mean           std     min      25%      50%  \
# work_year      275.0   2021.185455      0.703334  2020.0   2021.0   2021.0
# salary_in_usd  222.0  68110.265766  41599.378244  2859.0  39263.0  62726.0
# remote_ratio   275.0     63.272727     39.801265     0.0     50.0     50.0
#
#                    75%       max
# work_year       2022.0    2022.0
# salary_in_usd  88654.0  200000.0
# remote_ratio     100.0     100.0

# %%
tog.loc[(tog['company_location']=='US')].describe().T
# Out:
#                count           mean           std     min       25%       50%  \
# work_year      355.0    2021.552113      0.646123  2020.0    2021.0    2022.0
# salary_in_usd  296.0  144973.763514  67765.819055  5679.0  101377.5  136807.0
# remote_ratio   355.0      77.746479     39.922141     0.0      75.0     100.0
#
#                     75%       max
# work_year        2022.0    2022.0
# salary_in_usd  170000.0  450000.0
# remote_ratio      100.0     100.0

# %%
tog.loc[(tog['employee_residence']=='US')].describe().T
# Out:
#                count           mean           std      min       25%  \
# work_year      332.0    2021.587349      0.627821   2020.0    2021.0
# salary_in_usd  278.0  149849.122302  65907.399811  25000.0  105550.0
# remote_ratio   332.0      77.259036     40.420962      0.0      50.0
#
#                     50%       75%       max
# work_year        2022.0    2022.0    2022.0
# salary_in_usd  140000.0  174750.0  450000.0
# remote_ratio      100.0     100.0     100.0

# %%
otros_paises=tog.loc[(tog['company_location']!='US')].groupby('company_location').mean()['salary_in_usd']

otros_paises
# Out:
# company_location
# AE    100000.000000
# AS     18053.000000
# AT     76738.666667
# AU     87064.000000
# BE     85699.000000
#           ...
# SG     89294.000000
# SI     63831.000000
# TR     20096.666667
# UA     13400.000000
# VN      4000.000000
# Name: salary_in_usd, Length: 49, dtype: float64

# %%
plt.figure(figsize=(20,5))

y_pos = np.arange(len(otros_paises))

# Create bars
plt.bar(y_pos, otros_paises)

# Create names on the x-axis
plt.xticks(y_pos, otros_paises.index)
plt.xticks(rotation = 90)

# Show graphic
plt.show()

# %%
tog.loc[(tog['company_location']=='US')]
# Out:
#      work_year experience_level employment_type  job_title  salary_in_usd  \
# 0         2022               SE              FT   Engineer       140250.0
# 1         2022               SE              FT   Engineer       135000.0
# 2         2021               MI              FT    Analyst       100000.0
# 3         2021               SE              CT   Engineer       270000.0
# 4         2021               MI              FT   Engineer        26005.0
# ..         ...              ...             ...        ...            ...
# 101       2022               SE              FT    Analyst            NaN
# 102       2022               SE              FT    Analyst            NaN
# 103       2022               SE              FT  Principal            NaN
# 104       2022               SE              FT  Scientist            NaN
# 106       2022               SE              FT    Analyst            NaN
#
#     employee_residence  remote_ratio company_location company_size
# ...

# %%
testeo.company_location.groupby(testeo.company_location).count()
# Out:
# company_location
# AT     1
# AU     1
# BR     1
# CA     5
# CN     1
#       ..
# MX     2
# MY     1
# PL     1
# RU     2
# US    59
# Name: company_location, Length: 24, dtype: int64

# %%
country='MY'

pycountry.countries.get(alpha_2=country)
# Out:
# Country(alpha_2='MY', alpha_3='MYS', flag='🇲🇾', name='Malaysia', numeric='458')

# %%
pais='US'

#data6.loc[(data6['employee_residence']==pais) | (data6['company_location']==pais)]

# %%
tog=tog.fillna(0)

# %%
tog.loc[(tog.salary_in_usd>200000)]
tog.loc[(tog.job_title=='Principal')]
# Out:
#      work_year experience_level employment_type  job_title  salary_in_usd  \
# 14        2020               SE              FT  Principal       148261.0
# 16        2020               MI              FT  Principal        59303.0
# 19        2022               SE              FT  Principal       109280.0
# 42        2020               SE              FT  Principal       117104.0
# 45        2020               MI              FT  Principal       115000.0
# ..         ...              ...             ...        ...            ...
# 66        2022               SE              FT  Principal            0.0
# 80        2022               MI              FT  Principal            0.0
# 82        2022               EN              FT  Principal            0.0
# 90        2022               MI              FT  Principal            0.0
# 103       2022               SE              FT  Principal            0.0
#
#     employee_residence  remote_ratio company_location company_size
# ...

# %% [markdown]
# # Aquí quitar los outlayers

# %%
tog=tog.loc[(tog.salary_in_usd<200000)]

tog.shape
# Out:
# (552, 9)

# %%
'''tog.reset_index(drop=True, inplace=True)
principal=tog.loc[tog.job_title=='Principal']
menor_200=tog.loc[(tog.salary_in_usd<200000) & (tog.job_title!='Principal')]
df_final=pd.concat([principal, menor_200]).sort_index()'''
# Out:
# "tog.reset_index(drop=True, inplace=True)\nprincipal=tog.loc[tog.job_title=='Principal']\nmenor_200=tog.loc[(tog.salary_in_usd<200000) & (tog.job_title!='Principal')]\ndf_final=pd.concat([principal, menor_200]).sort_index()"

# %%
tog.employee_residence.unique()
# Out:
# array(['US', 'RO', 'FR', 'GR', 'SI', 'DE', 'IN', 'GB', 'PK', 'MD', 'JP',
#        'CA', 'PT', 'IE', 'AE', 'IT', 'MX', 'VN', 'BE', 'KE', 'ES', 'CH',
#        'CL', 'JE', 'TR', 'NZ', 'UA', 'AU', 'NG', 'BG', 'HK', 'EE', 'CZ',
#        'RU', 'PR', 'AT', 'BR', 'IR', 'NL', 'RS', 'HU', 'PL', 'HN', 'BO',
#        'MT', 'LU', 'SG', 'CN', 'PH', 'DK', 'HR', 'IQ', 'CO', 'AR', 'TN'],
#       dtype=object)

# %%
tog.company_location.unique()
# Out:
# array(['US', 'FR', 'GR', 'LU', 'SI', 'DE', 'IN', 'GB', 'PK', 'MD', 'JP',
#        'CA', 'AS', 'IE', 'AE', 'MX', 'VN', 'BE', 'KE', 'ES', 'CH', 'CL',
#        'CN', 'DK', 'TR', 'NZ', 'PL', 'UA', 'AU', 'NG', 'EE', 'CZ', 'AT',
#        'BR', 'IR', 'NL', 'HU', 'PT', 'HN', 'MT', 'RO', 'SG', 'IT', 'HR',
#        'IQ', 'IL', 'RU', 'CO', 'MY'], dtype=object)

# %%
tog.company_size.unique()
# Out:
# array(['M', 'L', 'S'], dtype=object)

# %%
life=pd.read_csv('../1-Input/Cost_of_Living_Index_2022.csv')

existing=[]
notexisting=[]
for i, country in enumerate(life.Country):
    if pycountry.countries.get(name=country)==None:
        country=country.replace('Czech Republic','CZ').replace('Iran','IR').replace('Russia','RU').replace('Vietnam','VN').replace('Moldova','MD').replace('Samoa','AS').replace('Bolivia','BO')
        existing.append(country)
    else:
        jap=pycountry.countries.get(name=country)
        jap=jap.alpha_2
        jap=jap.replace('WS','AS')
        
        existing.append(jap)

life['company_location']=existing
life['employee_residence']=existing
life
# Out:
#      Rank      Country  Cost_Living  Rent Index  \
# 0       1  Afghanistan        20.37        2.72
# 1       2      Albania        35.50        8.47
# 2       3      Algeria        26.87        4.59
# 3       4    Argentina        34.69        7.71
# 4       5      Armenia        33.89       11.61
# ..    ...          ...          ...         ...
# 135   136      Vietnam        37.48       13.22
# 136   137        Yemen        53.14        6.71
# 137   138       Zambia        33.04        9.26
# 138   139     Zimbabwe        45.68        8.75
# 139   140        Samoa        45.68        8.75
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                             12.09            14.92                   12.41
# 1                             22.83            29.32                   25.82
# 2                             16.43            28.82                   14.48
# ...

# %%
pycountry.countries.get(alpha_2='BO')
# Out:
# Country(alpha_2='BO', alpha_3='BOL', common_name='Bolivia', flag='🇧🇴', name='Bolivia, Plurinational State of', numeric='068', official_name='Plurinational State of Bolivia')

# %%
existing
# Out:
# ['AF',
#  'AL',
#  'DZ',
#  'AR',
#  'AM',
#  'AU',
#  'AT',
#  'AZ',
#  'BS',
#  'BH',
#  'BD',
#  'BB',
#  'BY',
#  'BE',
#  'BZ',
#  'BM',
#  'BO',
#  'BA',
#  'BW',
#  'BR',
#  'BG',
#  'KH',
#  'CM',
#  'CA',
#  'CL',
#  'CN',
#  'CO',
#  'CR',
#  'HR',
#  'CU',
#  'CY',
#  'CZ',
#  'DK',
#  'DO',
#  'EC',
#  'EG',
#  'SV',
#  'EE',
#  'ET',
#  'FJ',
#  'FI',
#  'FR',
#  'GE',
#  'DE',
#  'GH',
#  'GR',
#  'GT',
#  'GG',
#  'HN',
#  'HK',
#  'HU',
#  'IS',
#  'IN',
#  'ID',
#  'IR',
#  'IQ',
#  'IE',
#  'IL',
#  'IT',
#  'Ivory Coast',
#  'JM',
#  'JP',
#  'JE',
#  'JO',
#  'KZ',
#  'KE',
#  'Kosovo (Disputed Territory)',
#  'KW',
#  'LV',
#  'LB',
#  'LY',
#  'LT',
#  'LU',
#  'MO',
#  'MY',
#  'MV',
#  'MT',
#  'MU',
#  'MX',
#  'MD',
#  'MN',
#  'ME',
#  'MA',
#  'MM',
#  'NP',
#  'NL',
#  'NZ',
#  'NI',
#  'NG',
#  'MK',
#  'NO',
#  'OM',
#  'PK',
#  'Palestine',
#  'PA',
#  'PY',
#  'PE',
#  'PH',
#  'PL',
#  'PT',
#  'PR',
#  'QA',
#  'RO',
#  'RU',
#  'RW',
#  'SA',
# ...

# %%
life.loc[(life.Cost_Living.isna())]
# Out:
# Empty DataFrame
# Columns: [Rank, Country, Cost_Living, Rent Index, Cost of Living Plus Rent Index, Groceries Index, Restaurant Price Index, Local Purchasing Power Index, company_location, employee_residence]
# Index: []

# %%
pd.set_option('display.max_rows', 15)

# %%
data5=pd.merge(tog, life[['Cost_Living','company_location']] ,   on='company_location', how='left')

data5
# Out:
#      work_year experience_level employment_type  job_title  salary_in_usd  \
# 0         2022               SE              FT   Engineer       140250.0
# 1         2022               SE              FT   Engineer       135000.0
# 2         2021               MI              FT    Analyst       100000.0
# 3         2021               MI              FT   Engineer        26005.0
# 4         2022               MI              FT  Scientist       153000.0
# ..         ...              ...             ...        ...            ...
# 547       2022               SE              FT    Analyst            0.0
# 548       2022               SE              FT  Principal            0.0
# 549       2022               SE              FT  Scientist            0.0
# 550       2022               EN              FT    Analyst            0.0
# 551       2022               SE              FT    Analyst            0.0
#
#     employee_residence  remote_ratio company_location company_size  \
# ...

# %%
data5.rename(columns = {'Cost_Living':'Cost_Living_com'}, inplace = True)

data5
# Out:
#      work_year experience_level employment_type  job_title  salary_in_usd  \
# 0         2022               SE              FT   Engineer       140250.0
# 1         2022               SE              FT   Engineer       135000.0
# 2         2021               MI              FT    Analyst       100000.0
# 3         2021               MI              FT   Engineer        26005.0
# 4         2022               MI              FT  Scientist       153000.0
# ..         ...              ...             ...        ...            ...
# 547       2022               SE              FT    Analyst            0.0
# 548       2022               SE              FT  Principal            0.0
# 549       2022               SE              FT  Scientist            0.0
# 550       2022               EN              FT    Analyst            0.0
# 551       2022               SE              FT    Analyst            0.0
#
#     employee_residence  remote_ratio company_location company_size  \
# ...

# %%
data6=pd.merge(data5, life[['Cost_Living','employee_residence']] ,   on='employee_residence', how='left')

data6
# Out:
#      work_year experience_level employment_type  job_title  salary_in_usd  \
# 0         2022               SE              FT   Engineer       140250.0
# 1         2022               SE              FT   Engineer       135000.0
# 2         2021               MI              FT    Analyst       100000.0
# 3         2021               MI              FT   Engineer        26005.0
# 4         2022               MI              FT  Scientist       153000.0
# ..         ...              ...             ...        ...            ...
# 547       2022               SE              FT    Analyst            0.0
# 548       2022               SE              FT  Principal            0.0
# 549       2022               SE              FT  Scientist            0.0
# 550       2022               EN              FT    Analyst            0.0
# 551       2022               SE              FT    Analyst            0.0
#
#     employee_residence  remote_ratio company_location company_size  \
# ...

# %%
tog.loc[(tog['company_location']=='US')].describe().T
# Out:
#                count          mean           std     min      25%       50%  \
# work_year      302.0   2021.552980      0.648669  2020.0   2021.0    2022.0
# salary_in_usd  302.0  97966.208609  59208.318033     0.0  60000.0  110000.0
# remote_ratio   302.0     77.152318     40.238120     0.0     50.0     100.0
#
#                     75%       max
# work_year        2022.0    2022.0
# salary_in_usd  144000.0  192600.0
# remote_ratio      100.0     100.0

# %%
tog.loc[(tog['experience_level']=='EX')].describe().T
# Out:
#                count          mean           std     min     25%       50%  \
# work_year       17.0   2021.411765      0.618347  2020.0  2021.0    2021.0
# salary_in_usd   17.0  87622.176471  72353.291796     0.0     0.0  118187.0
# remote_ratio    17.0     73.529412     35.871503     0.0    50.0     100.0
#
#                     75%       max
# work_year        2022.0    2022.0
# salary_in_usd  141846.0  196979.0
# remote_ratio      100.0     100.0

# %%
tog.loc[(tog['experience_level']=='EN')].describe().T
# Out:
#                count          mean           std     min     25%      50%  \
# work_year       87.0   2021.022989      0.664324  2020.0  2021.0   2021.0
# salary_in_usd   87.0  34224.068966  31180.813493     0.0     0.0  25000.0
# remote_ratio    87.0     68.965517     37.541744     0.0    50.0    100.0
#
#                    75%       max
# work_year       2021.0    2022.0
# salary_in_usd  58568.5  100000.0
# remote_ratio     100.0     100.0

# %%
tog.loc[(tog['experience_level']=='MI')].describe().T
# Out:
#                count          mean           std     min       25%      50%  \
# work_year      202.0   2021.277228      0.714022  2020.0   2021.00   2021.0
# salary_in_usd  202.0  62651.292079  48468.572333     0.0  18402.25  62687.5
# remote_ratio   202.0     63.118812     42.772983     0.0      0.00    100.0
#
#                    75%       max
# work_year       2022.0    2022.0
# salary_in_usd  98158.0  170000.0
# remote_ratio     100.0     100.0

# %%
tog.loc[(tog['experience_level']=='SE')].describe().T
# Out:
#                count           mean           std     min       25%       50%  \
# work_year      246.0    2021.613821      0.620444  2020.0   2021.00    2022.0
# salary_in_usd  246.0  105302.699187  55416.767692     0.0  79093.25  114523.5
# remote_ratio   246.0      75.609756     40.084530     0.0     50.00     100.0
#
#                      75%       max
# work_year        2022.00    2022.0
# salary_in_usd  147695.75  192600.0
# remote_ratio      100.00     100.0

# %%
'''def exper(x):
    if x=='EX':
        x=132
    if x=='SE':
        x=120
    if x=='MI':
        x=63
    if x=='EN':
        x=37

    
    return x   

data6.experience_level=data6.experience_level.apply(lambda x: exper(x))

data6.experience_level.unique()'''
# Out:
# "def exper(x):\n    if x=='EX':\n        x=132\n    if x=='SE':\n        x=120\n    if x=='MI':\n        x=63\n    if x=='EN':\n        x=37\n\n    \n    return x   \n\ndata6.experience_level=data6.experience_level.apply(lambda x: exper(x))\n\ndata6.experience_level.unique()"

# %%
'''def teletrab(x):
    if x==100:
        x='cien'
    if x==50:
        x='cincuenta'
    if x==0:
        x='cero'
    
    return x   

data6.remote_ratio=data6.remote_ratio.apply(lambda x: teletrab(x))

data6.remote_ratio.unique()'''
# Out:
# "def teletrab(x):\n    if x==100:\n        x='cien'\n    if x==50:\n        x='cincuenta'\n    if x==0:\n        x='cero'\n    \n    return x   \n\ndata6.remote_ratio=data6.remote_ratio.apply(lambda x: teletrab(x))\n\ndata6.remote_ratio.unique()"

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 552 entries, 0 to 551
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           552 non-null    int64
#  1   experience_level    552 non-null    object
#  2   employment_type     552 non-null    object
#  3   job_title           552 non-null    object
#  4   salary_in_usd       552 non-null    float64
#  5   employee_residence  552 non-null    object
#  6   remote_ratio        552 non-null    int64
#  7   company_location    552 non-null    object
#  8   company_size        552 non-null    object
#  9   Cost_Living_com     552 non-null    float64
#  10  Cost_Living         552 non-null    float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 51.8+ KB

# %%
data6.loc[(data6.Cost_Living.isna())]
# Out:
# Empty DataFrame
# Columns: [work_year, experience_level, employment_type, job_title, salary_in_usd, employee_residence, remote_ratio, company_location, company_size, Cost_Living_com, Cost_Living]
# Index: []

# %%
plt.figure(figsize=(10, 6))

mask=np.triu(np.ones_like(data6[:500].corr(), dtype=bool))

cmap=sns.diverging_palette(0, 10, as_cmap=True)

sns.heatmap(data6[:500].corr(),
           #mask=mask,
          cmap=cmap,
          center=0,
          square=True,
          annot=True,
          linewidths=0.5,
          cbar_kws={'shrink': 0.5});

# %%
pd.plotting.scatter_matrix(data6[:500], figsize=(15, 10), alpha=0.2);

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 552 entries, 0 to 551
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           552 non-null    int64
#  1   experience_level    552 non-null    object
#  2   employment_type     552 non-null    object
#  3   job_title           552 non-null    object
#  4   salary_in_usd       552 non-null    float64
#  5   employee_residence  552 non-null    object
#  6   remote_ratio        552 non-null    int64
#  7   company_location    552 non-null    object
#  8   company_size        552 non-null    object
#  9   Cost_Living_com     552 non-null    float64
#  10  Cost_Living         552 non-null    float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 51.8+ KB

# %%
data6.drop(['employment_type'], axis=1, inplace=True)
data6.drop(['employee_residence'], axis=1, inplace=True)
data6.drop(['company_location'], axis=1, inplace=True)
data6.drop(['work_year'], axis=1, inplace=True)

# %%
data6
# Out:
#     experience_level  job_title  salary_in_usd  remote_ratio company_size  \
# 0                 SE   Engineer       140250.0           100            M
# 1                 SE   Engineer       135000.0           100            M
# 2                 MI    Analyst       100000.0           100            M
# 3                 MI   Engineer        26005.0             0            L
# 4                 MI  Scientist       153000.0            50            M
# ..               ...        ...            ...           ...          ...
# 547               SE    Analyst            0.0           100            M
# 548               SE  Principal            0.0           100            M
# 549               SE  Scientist            0.0           100            M
# 550               EN    Analyst            0.0             0            M
# 551               SE    Analyst            0.0             0            M
#
#      Cost_Living_com  Cost_Living
# 0             123.35       123.35
# ...

# %%
data6=pd.get_dummies(data6, columns=['company_size','job_title','experience_level'])   # drop_first=True, por defecto es False

# %%
data6
# Out:
#      salary_in_usd  remote_ratio  Cost_Living_com  Cost_Living  \
# 0         140250.0           100           123.35       123.35
# 1         135000.0           100           123.35       123.35
# 2         100000.0           100           123.35       123.35
# 3          26005.0             0           123.35        35.24
# 4         153000.0            50           123.35       123.35
# ..             ...           ...              ...          ...
# 547            0.0           100           123.35       123.35
# 548            0.0           100           123.35       123.35
# 549            0.0           100           123.35       123.35
# 550            0.0             0           100.00       100.00
# 551            0.0             0           123.35       123.35
#
#      company_size_L  company_size_M  company_size_S  job_title_Analyst  \
# 0                 0               1               0                  0
# ...

# %%
corte=len(data6)-107

corte
# Out:
# 445

# %%
X=data6.iloc[0:corte]

X
# Out:
#      salary_in_usd  remote_ratio  Cost_Living_com  Cost_Living  \
# 0         140250.0           100           123.35       123.35
# 1         135000.0           100           123.35       123.35
# 2         100000.0           100           123.35       123.35
# 3          26005.0             0           123.35        35.24
# 4         153000.0            50           123.35       123.35
# ..             ...           ...              ...          ...
# 440       100000.0           100           123.35       123.35
# 441         5882.0             0           123.35        50.00
# 442        90700.0           100           100.00       100.00
# 443        82528.0           100            80.65        80.65
# 444        70000.0           100           123.35       123.35
#
#      company_size_L  company_size_M  company_size_S  job_title_Analyst  \
# 0                 0               1               0                  0
# ...

# %%
test=data6.iloc[corte:]

test
# Out:
#      salary_in_usd  remote_ratio  Cost_Living_com  Cost_Living  \
# 445            0.0             0            77.03        77.03
# 446            0.0           100           123.35       123.35
# 447            0.0           100           123.35       123.35
# 448            0.0             0            41.77        41.77
# 449            0.0           100            50.00        50.00
# ..             ...           ...              ...          ...
# 547            0.0           100           123.35       123.35
# 548            0.0           100           123.35       123.35
# 549            0.0           100           123.35       123.35
# 550            0.0             0           100.00       100.00
# 551            0.0             0           123.35       123.35
#
#      company_size_L  company_size_M  company_size_S  job_title_Analyst  \
# 445               0               0               1                  0
# ...

# %%
test.drop(['salary_in_usd'], axis=1, inplace=True)

test.shape
# Out:
# C:\Users\David MC\AppData\Local\Temp\ipykernel_8604\2346692334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop(['salary_in_usd'], axis=1, inplace=True)
# (107, 14)

# %%
y=X.salary_in_usd

y
# Out:
# 0      140250.0
# 1      135000.0
# 2      100000.0
# 3       26005.0
# 4      153000.0
#          ...
# 440    100000.0
# 441      5882.0
# 442     90700.0
# 443     82528.0
# 444     70000.0
# Name: salary_in_usd, Length: 445, dtype: float64

# %%
X= X.drop(['salary_in_usd'], axis=1)

# %%
X.shape, y.shape
# Out:
# ((445, 14), (445,))

# %%
#from sklearn.preprocessing import StandardScaler
#X=StandardScaler().fit_transform(X)

# %%
from sklearn.linear_model import LogisticRegression 

from sklearn.model_selection import train_test_split as tts

# %%
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.linear_model import Lasso        # regularizacion L1
from sklearn.linear_model import Ridge        # regularizacion L2
from sklearn.linear_model import ElasticNet   # regularizacion L1+L2
from sklearn.ensemble import RandomForestRegressor as RFR  
from sklearn.tree import ExtraTreeRegressor as ETR
from sklearn.svm import SVR  # support vector regressor
from sklearn.ensemble import GradientBoostingRegressor as GBR
from xgboost import XGBRegressor as XGBR
from catboost import CatBoostRegressor as CTR
from lightgbm import LGBMRegressor as LGBMR

# se inician los modelos
linreg=LinReg()
lasso=Lasso()
ridge=Ridge()
elastic=ElasticNet()
svr=SVR()
rfr=RFR(n_estimators=2000)
etr=ETR()
gbr=GBR()
xgbr=XGBR()
ctr=CTR()
lgbmr=LGBMR()

# %%
from sklearn.metrics import mean_squared_error as mse  # error cuadratico medio
from sklearn.metrics import r2_score as r2

# %%
'''linreg.fit(X_train, y_train)
lasso.fit(X_train, y_train)
ridge.fit(X_train, y_train)
elastic.fit(X_train, y_train)
svr.fit(X_train, y_train)
rfr.fit(X_train, y_train)
etr.fit(X_train, y_train)
gbr.fit(X_train, y_train)
xgbr.fit(X_train, y_train)
ctr.fit(X_train, y_train, verbose=0)
lgbmr.fit(X_train, y_train)'''

'''linreg.predict(X_test)
lasso.predict(X_test)
ridge.predict(X_test)
elastic.predict(X_test)
svr.predict(X_test)
rfr.predict(X_test)
etr.predict(X_test)
gbr.predict(X_test)
xgbr.predict(X_test)
ctr.predict(X_test)
lgbmr.predict(X_test)[:10]'''
# Out:
# 'linreg.predict(X_test)\nlasso.predict(X_test)\nridge.predict(X_test)\nelastic.predict(X_test)\nsvr.predict(X_test)\nrfr.predict(X_test)\netr.predict(X_test)\ngbr.predict(X_test)\nxgbr.predict(X_test)\nctr.predict(X_test)\nlgbmr.predict(X_test)[:10]'

# %%
X_train, X_test, y_train, y_test=tts(X, y, random_state=42, test_size=0.01)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((440, 14), (5, 14), (440,), (5,))

# %%
'''from sklearn.preprocessing import StandardScaler
X_train=StandardScaler().fit_transform(X_train)
X_test=StandardScaler().fit_transform(X_test)
test=StandardScaler().fit_transform(test)'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\nX_train=StandardScaler().fit_transform(X_train)\nX_test=StandardScaler().fit_transform(X_test)\ntest=StandardScaler().fit_transform(test)'

# %%
#X_train_03=X_train

# %%
#X_train_02=X_train

# %%
modelos=[linreg, lasso, ridge, elastic, svr, rfr, etr, gbr, xgbr, ctr, lgbmr]

modelos_name=['linreg', 'lasso', 'ridge', 'elastic', 'svr', 'rfr', 'etr', 'gbr', 'xgbr', 'ctr', 'lgbmr']

mse_testeo=[]
mse_train=[]
erre_testeo=[]
erre_train=[]

for i,m in enumerate(modelos):
    if modelos_name[i]=='ctr':
        m.fit(X_train, y_train, verbose=0)

    else:
        m.fit(X_train, y_train)
    
    m.predict(X_test)[:10]
    
    y_pred=m.predict(X_test)
    y_pred_train=m.predict(X_train)
    
    
    mse_testeo.append(mse(y_test, y_pred, squared=False))
    mse_train.append(mse(y_train, y_pred_train, squared=False))
    erre_testeo.append(r2(y_test, y_pred))
    erre_train.append(r2(y_train, y_pred_train))
    

analisis= pd.DataFrame({"modelos" : modelos_name, "mse_testeo" : mse_testeo, "mse_train" : mse_train, "erre2_testeo" : erre_testeo, "erre2_train" : erre_train})

analisis
# Out:
#     modelos    mse_testeo     mse_train  erre2_testeo  erre2_train
# 0    linreg  32150.713571  25936.352134      0.116342     0.697431
# 1     lasso  32149.439519  25936.353514      0.116412     0.697431
# 2     ridge  32113.539851  25941.498055      0.118384     0.697311
# 3   elastic  32584.194544  29805.358166      0.092353     0.600428
# 4       svr  35690.592016  47156.515058     -0.088956    -0.000206
# 5       rfr  28090.761220  19380.445297      0.325425     0.831060
# 6       etr  29412.847274  18408.008890      0.260434     0.847588
# 7       gbr  29688.672431  21676.040097      0.246498     0.788668
# 8      xgbr  29411.544850  18409.624850      0.260499     0.847561
# 9       ctr  27407.679697  18882.385277      0.357834     0.839631
# 10    lgbmr  28879.915414  21891.527671      0.286991     0.784445

# %%
dict(zip(X_train.columns, linreg.coef_))
# Out:
# {'remote_ratio': 52.73780014817203,
#  'Cost_Living_com': 186.4914673533201,
#  'Cost_Living': 691.8388369187586,
#  'company_size_L': 4046.3714922313284,
#  'company_size_M': 1254.9411828775376,
#  'company_size_S': -5301.3126751088785,
#  'job_title_Analyst': -18813.690840885152,
#  'job_title_Engineer': 1157.899049730396,
#  'job_title_Principal': 16828.527797676987,
#  'job_title_Scientist': 827.2639934777353,
#  'experience_level_EN': -33108.43131771082,
#  'experience_level_EX': 34274.41659304491,
#  'experience_level_MI': -12034.884186229043,
#  'experience_level_SE': 10868.898910894986}

# %%
y_pred_ctr=ctr.predict(test)

# %%
y_pred_lgbmr=lgbmr.predict(test)

# %%
y_pred_elegido=lgbmr.predict(test)

# %%
y_pred_elegido
# Out:
# array([ 85229.35182067, 143913.37633316, 112861.91668991,  27837.4487252 ,
#         29948.33893493,  62814.32898694,  89296.90848164,  56915.10444147,
#         25383.23756917, 146720.34396963,  46732.85392889, 151953.85778897,
#         68779.80747336,  45749.672155  ,  68532.55843193,  51051.2162228 ,
#         86205.40915728, 115977.85576   ,  45384.84397332,  73483.97043306,
#         33544.90090191,  68742.2843602 ,  78596.36116508, 148428.74068918,
#         16643.60333154,  17839.87545571,  87260.31079288, 141133.65700234,
#         85521.97646788,  74972.1052677 ,  60103.70973534,  75872.33362489,
#         53568.88891113,  70298.76364526,  18228.48508428,  76612.82506821,
#        136439.85228742,  14587.22995099,  59120.77072171, 161987.86381718,
#         43304.39444163,  31501.23342942, 112861.91668991, 157615.35264603,
#         85634.0982606 , 162747.9457639 , 101412.41338594,  59120.77072171,
# ...

# %%
for i, pred in enumerate(y_pred_elegido):
    if i==13 or i==40:
        y_pred_elegido[i]=pred/2

y_pred_elegido
# Out:
# array([ 85229.35182067, 143913.37633316, 112861.91668991,  27837.4487252 ,
#         29948.33893493,  62814.32898694,  89296.90848164,  56915.10444147,
#         25383.23756917, 146720.34396963,  46732.85392889, 151953.85778897,
#         68779.80747336,  22874.8360775 ,  68532.55843193,  51051.2162228 ,
#         86205.40915728, 115977.85576   ,  45384.84397332,  73483.97043306,
#         33544.90090191,  68742.2843602 ,  78596.36116508, 148428.74068918,
#         16643.60333154,  17839.87545571,  87260.31079288, 141133.65700234,
#         85521.97646788,  74972.1052677 ,  60103.70973534,  75872.33362489,
#         53568.88891113,  70298.76364526,  18228.48508428,  76612.82506821,
#        136439.85228742,  14587.22995099,  59120.77072171, 161987.86381718,
#         21652.19722081,  31501.23342942, 112861.91668991, 157615.35264603,
#         85634.0982606 , 162747.9457639 , 101412.41338594,  59120.77072171,
# ...

# %%
test['salary']=y_pred_elegido

test.head(20)
# Out:
# C:\Users\David MC\AppData\Local\Temp\ipykernel_8604\2698897038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['salary']=y_pred_elegido
#      remote_ratio  Cost_Living_com  Cost_Living  company_size_L  \
# 445             0            77.03        77.03               0
# 446           100           123.35       123.35               1
# 447           100           123.35       123.35               1
# 448             0            41.77        41.77               0
# 449           100            50.00        50.00               1
# ..            ...              ...          ...             ...
# 460            50            74.13        74.13               0
# 461           100            75.58        75.58               1
# ...

# %%
index_lst = [i for i in range(107)]
results= pd.DataFrame({"id" : index_lst, "salary_in_usd" : y_pred_elegido})
results.to_csv("predict7.csv", index=False)

# %%
plt.figure(figsize=(30, 15))

mask=np.triu(np.ones_like(test.corr(), dtype=bool))

cmap=sns.diverging_palette(0, 10, as_cmap=True)

sns.heatmap(test.corr(),
           #mask=mask,
          cmap=cmap,
          center=0,
          square=True,
          annot=True,
          linewidths=0.5,
          cbar_kws={'shrink': 0.5});

# %%
testeo['salary_in_usd']=y_pred_ctr

testeo.head(20)
# Out:
#     work_year experience_level employment_type  \
# 0        2020               SE              FT
# 1        2020               MI              FT
# 2        2020               MI              FT
# 3        2020               MI              FT
# 4        2020               MI              FT
# ..        ...              ...             ...
# 15       2020               MI              FT
# 16       2021               SE              FT
# 17       2021               MI              FT
# 18       2021               EN              FT
# 19       2021               MI              FT
#
#                             job_title employee_residence  remote_ratio  \
# 0          Machine Learning Scientist                 JP             0
# 1                   Lead Data Analyst                 US           100
# 2                        Data Analyst                 US           100
# 3           Machine Learning Engineer                 CN             0
# ...

# %%
plt.figure(figsize=(10,7))

plt.scatter(testeo.salary_in_usd, testeo.job_title)
plt.xlabel('salary')
plt.ylabel('descrip');

# %%
plt.figure(figsize=(10,7))

plt.scatter(testeo.salary_in_usd, testeo.company_location	)
plt.xlabel('salary')
plt.ylabel('descrip');

# %%
plt.figure(figsize=(10,7))

plt.scatter(testeo.salary_in_usd, testeo.experience_level)
plt.xlabel('salary')
plt.ylabel('descrip');
